# %%
import matplotlib
import pandas as pd
import seaborn as sns

# %%
#Load CSV
figures_dataframe = pd.read_csv("figures_dataset.txt",sep=" ")
figures_dataframe.head()
# Out:
#   Figure_name       ph1       ph2
# 0           A  0.211829  0.211829
# 1           A  0.211800  0.211800
# 2           A  0.225643  0.225643
# 3           A  0.225680  0.225680
# 4           A  0.159491  0.159491

# %%
# Use the 'hue' argument to provide a factor variable
sns.lmplot( x="ph1", y="ph2", data=figures_dataframe, fit_reg=False, hue='Figure_name', legend=True)
 
# Move the legend to an empty part of the plot
plt.legend(loc='lower right')
# Out:
# No handles with labels found to put in legend.
